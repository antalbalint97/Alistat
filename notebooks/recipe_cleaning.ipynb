# %%
import ast
import pandas as pd

# Fájl elérési útja
file_path_alapanyagok = r"C:\Users\Bálint\Desktop\Asztal\Projekt\alapanyagok_jav.csv"
file_path_receptek = r"C:\Users\Bálint\Desktop\Asztal\Projekt\receptek.csv"

# Fájl beolvasása DataFrame-ként
df_alapanyagok = pd.read_csv(file_path_alapanyagok, encoding='utf-8')
df_receptek = pd.read_csv(file_path_receptek, encoding='utf-8')
#Converting the wrongly scraped ingredients column to a dictionary using ast
df_receptek["Hozzávalók"] = df_receptek["Hozzávalók"].apply(ast.literal_eval)

# %%
import pandas as pd
import re

class DataCleaner:
    """Class for cleaning and processing nutritional data."""

    def __init__(self, df=None):
        """Initialize with a DataFrame if provided."""
        self.df = df

    @staticmethod
    def convert_measures(df):
        """Convert µg values to grams for selected nutrient columns."""
        columns_to_convert = [
            "Folát", "Béta-karotin", "Lutein+zeaxantin", "K vitamin", "A vitamin", 
            "Likopin", "Alfa-karotin", "Béta-kriptoxantin", "Retinol", "Folsav", "Szelén"
        ]
        for col in columns_to_convert:
            if col in df.columns:
                df[col] = df[col] / 1_000_000  # Convert µg to g
        return df

    @staticmethod
    def detect_outliers(df, threshold=1000):
        """Detect unusually high values in numeric columns."""
        exceptions = {
            "tojássárgája": "koleszterin",
            "sertés agyvelő": "koleszterin",
            "sertésvelő": "koleszterin",
            "marhavelő": "koleszterin",
            "szárított rák": "koleszterin"
        }

        for col in df.columns:
            if col != "Alapanyag neve":
                df[col] = pd.to_numeric(df[col], errors="coerce")

        outlier_rows = []
        for col in df.columns:
            if col != "Alapanyag neve":
                high_values = df[df[col] > threshold]

                for _, row in high_values.iterrows():
                    if row["Alapanyag neve"] in exceptions and exceptions[row["Alapanyag neve"]] == col:
                        continue  # Skip known exceptions

                    outlier_rows.append({
                        "Alapanyag neve": row["Alapanyag neve"],
                        "Tápanyag": col,
                        "Érték": row[col]
                    })
        
        return pd.DataFrame(outlier_rows)

    @staticmethod
    def extract_unit(amount):
        """Extracts the unit from a quantity string."""
        match = re.search(r'[^\d\s,.]+$', amount)  # Extract last non-numeric part
        return match.group() if match else None

    def get_unique_units(self, column="Hozzávalók"):
        """Find unique measurement units from the ingredients column."""
        unique_units = set()
        for ingredients in self.df[column]:
            for ingredient in ingredients:
                unit = self.extract_unit(ingredient["Mennyiség"])
                if unit:
                    unique_units.add(unit)
        return unique_units

    @staticmethod
    def convert_to_100g(amount, unit_to_grams):
        """Convert ingredient amounts to a proportion of 100g."""
        num_match = re.search(r"[-+]?\d*\.?\d+", amount)
        unit_match = re.search(r'[^\d\s,.]+$', amount)
        
        unit_to_grams = {
            "g": 1,             # 1 gram = 1 gram
            "dkg": 10,          # 1 dkg = 10 grams
            "kg": 1000,         # 1 kg = 1000 grams
            "ml": 1,            # 1 ml ≈ 1 gram (for water-based liquids)
            "l": 1000,          # 1 liter = 1000 grams
            "dl": 100,          # 1 dl ≈ 100 grams
            "tk": 5,            # 1 teáskanál (teaspoon) ≈ 5 grams
            "kk": 3,            # 1 kávéskanál (coffee spoon) ≈ 3 grams
            "ek": 10,           # 1 evőkanál (tablespoon) ≈ 10 grams
            "teáskanál": 5,     # Same as "tk" (teaspoon)
            "evőkanál": 10,     # Same as "ek" (tablespoon)
            "bögre": 250,       # 1 bögre (cup) ≈ 250 grams (varies by ingredient)
            "csésze": 200,      # 1 csésze (cup) ≈ 200 grams (varies by ingredient)
            "csipet": 1,        # 1 csipet = small pinch ≈ 1 gram
            "késhegynyi": 2,    # 1 késhegynyi (knife tip amount) ≈ 2 grams
            "csepp": 0.05,      # 1 csepp (drop) ≈ 0.05 grams
            "tasak": 10,        # 1 tasak (packet) ≈ 10 grams (common for yeast, spices)
            "doboz": 400,       # 1 doboz (box) ≈ 400 grams (e.g., canned food)
            "csomag": 500,      # 1 csomag (pack) ≈ 500 grams (e.g., pasta, flour)
            "tubus": 100,       # 1 tubus (tube) ≈ 100 grams (e.g., tomato paste)
            "szál": 15,         # 1 szál (stalk) ≈ 15 grams (e.g., green onion, celery)
            "szelet": 30,       # 1 szelet (slice) ≈ 30 grams (e.g., bread, cheese)
            "szem": 5,          # 1 szem (piece) ≈ 5 grams (e.g., nut, seed, grape)
            "gerezd": 5,        # 1 gerezd (clove) ≈ 5 grams (e.g., garlic)
            "fej": 15,         # 1 fej (head) ≈ 200 grams (e.g., onion, garlic, cabbage)
            "csokor": 10,       # 1 csokor (bunch) ≈ 50 grams (e.g., parsley, dill)
            "levél": 1,         # 1 levél (leaf) ≈ 1 gram (e.g., basil, lettuce)
            "hüvelykujjnyi": 3,# 1 hüvelykujjnyi (thumb-sized) ≈ 25 grams (e.g., butter)
            "marék": 25,        # 1 marék (handful) ≈ 30 grams
            "maréknyi": 25,     # Same as "marék" (handful)
            "szár": 10,         # 1 szár (stalk) ≈ 15 grams
            "üveg": 500,        # 1 üveg (bottle) ≈ 500 grams (e.g., honey, oil)
            "szerint": None,    # "Ízlés szerint" (to taste) cannot be converted
            "nyert": None,      # Unknown meaning, needs manual adjustment
            "gr)": None         # Possible typo for "g"
        }

        if not num_match or not unit_match:
            return None  # If missing number or unit, return None

        num = float(num_match.group())
        unit = unit_match.group()

        if unit == "db":
            return 1  # Default proportion for single items

        if unit in unit_to_grams and unit_to_grams[unit]:
            return (num * unit_to_grams[unit]) / 100  # Normalize to 100g
        else:
            return None  # Unknown or unconvertible unit

# %%
def calculate_recipe_nutrition(df_receptek, df_alapanyagok):
    # Convert nutritional values to float to prevent TypeError
    for col in df_alapanyagok.columns:
        if col != 'Alapanyag neve':  
            df_alapanyagok[col] = pd.to_numeric(df_alapanyagok[col], errors='coerce')

    # Create a fast lookup set of ingredient names
    alapanyagok_set = set(df_alapanyagok['Alapanyag neve'])
    mismatching_ingredients = []  
    log_entries = []  
    calculated_nutrition = []

    # Iterate over only the first recipe
    row = df_receptek.iloc[0]  # Select only the first row
    recipe_name = row['Recept neve']
    ingredients_list = row['Hozzávalók']  # List of dictionaries

    # Dictionary to store aggregated nutrition values
    aggregated_nutrition = {col: 0 for col in df_alapanyagok.columns if col != 'Alapanyag neve'}

    # Iterate over ingredients
    for ingredient in ingredients_list:
        name = ingredient['Hozzávaló']
        amount = ingredient['Mennyiség']

        # Convert amount to proportion of 100g
        proportion_100g = convert_to_100g(amount)
        ingredient["Proportion_100g"] = proportion_100g

        if proportion_100g is None:
            mismatching_ingredients.append(name)
            continue

        # Check if ingredient exists in nutritional data
        if name not in alapanyagok_set:
            mismatching_ingredients.append(name)
            continue

        # Get nutritional values from df_alapanyagok
        matching_ingredient = df_alapanyagok[df_alapanyagok['Alapanyag neve'] == name]
        ingredient_nutrition = {col: 0 for col in df_alapanyagok.columns if col != 'Alapanyag neve'}

        for col in ingredient_nutrition.keys():
            if col in df_alapanyagok.columns:
                value = matching_ingredient.iloc[0][col]
                if pd.notna(value):  # Ensure it's a number
                    ingredient_nutrition[col] = float(value) * proportion_100g
        
        # Add ingredient-level nutrition to total
        for col in aggregated_nutrition.keys():
            aggregated_nutrition[col] += ingredient_nutrition[col]
    
    calculated_nutrition.append(aggregated_nutrition)

#     # Compare original and calculated values
#     log_entry = []
#     for col, calculated_value in aggregated_nutrition.items():
#         original_value = row.get(col, np.nan)  # Get original value or NaN

#         if not (pd.isna(original_value) and pd.isna(calculated_value)) and not np.isclose(original_value, calculated_value, atol=0.01):
#             log_entry.append({
#                 'Recept neve': recipe_name,
#                 'Eltérés': col,
#                 'Eredeti érték': original_value,
#                 'Számolt érték': calculated_value
#             })

#     # Save log if there are discrepancies
#     if log_entry:
#         log_df = pd.DataFrame(log_entry)
#         log_df.to_csv(f'{recipe_name}_recalculated_nutrition.csv', index=False)

#     # Add the calculated nutrition values to the DataFrame
#     df_receptek.at[0, 'Számolt tápértékek'] = aggregated_nutrition

#     # Print missing ingredients
#     print("Hiányzó hozzávalók listája:", set(mismatching_ingredients))

    return df_receptek

# %%
# Running the function
df_receptek = calculate_recipe_nutrition(df_receptek, df_alapanyagok)

# %%
df_filtered = df_receptek[df_receptek["Recept neve"] == "Csavaros lasagne"]
df_filtered.to_csv("filtered_recept.csv", index=False)

# %%
for col in df_alapanyagok.columns:
    if col != 'Alapanyag neve':  
        df_alapanyagok[col] = pd.to_numeric(df_alapanyagok[col], errors='coerce')

# Create a fast lookup set of ingredient names
alapanyagok_set = set(df_alapanyagok['Alapanyag neve'])
mismatching_ingredients = []  
log_entries = []  
calculated_nutrition = []

# Iterate over only the first recipe
row = df_receptek.iloc[0]  # Select only the first row
recipe_name = row['Recept neve']
ingredients_list = row['Hozzávalók']  # List of dictionaries

# Dictionary to store aggregated nutrition values
aggregated_nutrition = {col: 0 for col in df_alapanyagok.columns if col != 'Alapanyag neve'}

# Iterate over ingredients
for ingredient in ingredients_list:
    name = ingredient['Hozzávaló']
    amount = ingredient['Mennyiség']

    # Convert amount to proportion of 100g
    proportion_100g = convert_to_100g(amount)
    ingredient["Proportion_100g"] = proportion_100g

    if proportion_100g is None:
        mismatching_ingredients.append(name)
        continue

    # Check if ingredient exists in nutritional data
    if name not in alapanyagok_set:
        mismatching_ingredients.append(name)
        continue

    # Get nutritional values from df_alapanyagok
    matching_ingredient = df_alapanyagok[df_alapanyagok['Alapanyag neve'] == name]
    ingredient_nutrition = {col: 0 for col in df_alapanyagok.columns if col != 'Alapanyag neve'}

    for col in ingredient_nutrition.keys():
        if col in df_alapanyagok.columns:
            value = matching_ingredient.iloc[0][col]
            if pd.notna(value):  # Ensure it's a number
                ingredient_nutrition[col] = float(value) * proportion_100g

    # Debug print for ingredient-level calculations
    print(f"Ingredient: {name}, Proportion_100g: {proportion_100g}, Nutrition: {ingredient_nutrition}")

    # Add ingredient-level nutrition to total
    for col in aggregated_nutrition.keys():
        aggregated_nutrition[col] += ingredient_nutrition[col]

# # Debug print for final aggregated nutrition
# print(f"Final aggregated nutrition for {recipe_name}: {aggregated_nutrition}")

calculated_nutrition.append(aggregated_nutrition)
# Out:
# Ingredient: vöröshagyma, Proportion_100g: 2.0, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 2.2, 'Zsír': 0.144, 'Szénhidrát': 18.68, 'Víz': 178.22, 'Foszfor': 0.058, 'Magnézium': 0.02, 'Nátrium': 0.008, 'Kalcium': 0.046, 'B6 vitamin': 0.24, 'Kolin': 0.0121999999999998, 'Niacin - B3 vitamin': 0.000232, 'C vitamin': 0.0148, 'Telített zsírsav': 0.084, 'Többszörösen telített zsírsav': 0.034, 'Vas': 0.0004199999999998, 'Cink': 0.00034, 'Réz': 7.8e-05, 'Mangán': 0.000258, 'Szelén': 1.0, 'Rost': 3.4, 'Cukor': 8.48, 'Tiamin - B1 vitamin': 9.2e-05, 'Riboflavin - B2 vitamin': 5.4e-05, 'Pantoténsav - B5 vitamin': 0.000246, 'Folát': 38.0, 'E vitamin': 4e-05, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0.026, 'Béta-karotin': 2.0, 'Lutein+zeaxantin': 8.0, 'K vitamin': 0.8, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: sárgarépa, Proportion_100g: 1, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 0.93, 'Zsír': 0.146, 'Szénhidrát': 9.58, 'Víz': 88.29, 'Foszfor': 0.035, 'Magnézium': 0.012, 'Nátrium': 0.069, 'Kalcium': 0.033, 'B6 vitamin': 0.138, 'Kolin': 0.0088, 'Niacin - B3 vitamin': 0.000983, 'C vitamin': 0.0059, 'Telített zsírsav': 0.032, 'Többszörösen telített zsírsav': 0.102, 'Vas': 0.0003, 'Cink': 0.0002399999999999, 'Réz': 4.5e-05, 'Mangán': 0.0001429999999999, 'Szelén': 0.1, 'Rost': 2.8, 'Cukor': 4.74, 'Tiamin - B1 vitamin': 6.6e-05, 'Riboflavin - B2 vitamin': 5.8e-05, 'Pantoténsav - B5 vitamin': 0.000273, 'Folát': 19.0, 'E vitamin': 0.00066, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0.012, 'Béta-karotin': 8285.0, 'Lutein+zeaxantin': 256.0, 'K vitamin': 13.2, 'A vitamin': 835.0, 'Likopin': 1.0, 'Alfa-karotin': 3477.0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: zeller, Proportion_100g: 1, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 1.5, 'Zsír': 0.285, 'Szénhidrát': 9.2, 'Víz': 88.0, 'Foszfor': 0.115, 'Magnézium': 0.02, 'Nátrium': 0.1, 'Kalcium': 0.043, 'B6 vitamin': 0.165, 'Kolin': 0.009, 'Niacin - B3 vitamin': 0.0007, 'C vitamin': 0.008, 'Telített zsírsav': 0.079, 'Többszörösen telített zsírsav': 0.148, 'Vas': 0.0007, 'Cink': 0.00033, 'Réz': 7.000000000000001e-05, 'Mangán': 0.000158, 'Szelén': 0.7, 'Rost': 1.8, 'Cukor': 1.6, 'Tiamin - B1 vitamin': 5e-05, 'Riboflavin - B2 vitamin': 6e-05, 'Pantoténsav - B5 vitamin': 0.000352, 'Folát': 8.0, 'E vitamin': 0.0003599999999999, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0.058, 'Béta-karotin': 0, 'Lutein+zeaxantin': 1.0, 'K vitamin': 41.0, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: pulykamellsonka, Proportion_100g: 0.5, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 8.5, 'Zsír': 0.0, 'Szénhidrát': 0.5, 'Víz': 0.0, 'Foszfor': 0, 'Magnézium': 0, 'Nátrium': 0, 'Kalcium': 0, 'B6 vitamin': 0, 'Kolin': 0, 'Niacin - B3 vitamin': 0, 'C vitamin': 0, 'Telített zsírsav': 0, 'Többszörösen telített zsírsav': 0, 'Vas': 0, 'Cink': 0, 'Réz': 0, 'Mangán': 0, 'Szelén': 0, 'Rost': 0, 'Cukor': 0, 'Tiamin - B1 vitamin': 0, 'Riboflavin - B2 vitamin': 0, 'Pantoténsav - B5 vitamin': 0, 'Folát': 0, 'E vitamin': 0, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0, 'Béta-karotin': 0, 'Lutein+zeaxantin': 0, 'K vitamin': 0, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: olívaolaj, Proportion_100g: 0.3, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 0.0, 'Zsír': 29.1876, 'Szénhidrát': 0.0, 'Víz': 0.0, 'Foszfor': 0, 'Magnézium': 0, 'Nátrium': 0.0006, 'Kalcium': 0.0003, 'B6 vitamin': 0, 'Kolin': 8.999999999999999e-05, 'Niacin - B3 vitamin': 0, 'C vitamin': 0, 'Telített zsírsav': 4.142399999999999, 'Többszörösen telített zsírsav': 3.1569, 'Vas': 0.000168, 'Cink': 0, 'Réz': 0, 'Mangán': 0, 'Szelén': 0, 'Rost': 0, 'Cukor': 0, 'Tiamin - B1 vitamin': 0, 'Riboflavin - B2 vitamin': 0, 'Pantoténsav - B5 vitamin': 0, 'Folát': 0, 'E vitamin': 0.004305, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 21.888299999999997, 'Béta-karotin': 0, 'Lutein+zeaxantin': 0, 'K vitamin': 18.06, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: csirke, Proportion_100g: 4.0, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 74.4, 'Zsír': 300055.12, 'Szénhidrát': 0.0, 'Víz': 263.96, 'Foszfor': 0.588, 'Magnézium': 0.08, 'Nátrium': 0.28, 'Kalcium': 0.044, 'B6 vitamin': 1.4, 'Kolin': 0.2388, 'Niacin - B3 vitamin': 0.027204, 'C vitamin': 0.0064, 'Telített zsírsav': 17.24, 'Többszörösen telített zsírsav': 12.92, 'Vas': 0.0036, 'Cink': 0.00524, 'Réz': 0.000192, 'Mangán': 7.6e-05, 'Szelén': 57.6, 'Rost': 0, 'Cukor': 0, 'Tiamin - B1 vitamin': 0.00024, 'Riboflavin - B2 vitamin': 0.0004799999999996, 'Pantoténsav - B5 vitamin': 0.00364, 'Folát': 24.0, 'E vitamin': 0.0012, 'D vitamin': 40.0, 'B12 vitamin': 1.24, 'Egyszeresen telített zsírsav': 24.96, 'Béta-karotin': 0, 'Lutein+zeaxantin': 0, 'K vitamin': 6.0, 'A vitamin': 164.0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 300.0, 'Retinol': 164.0, 'Folsav': 0}
# Ingredient: rozmaring, Proportion_100g: 0.02, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 0.06620000000000001, 'Zsír': 0.09798, 'Szénhidrát': 0.414, 'Víz': 1.3554, 'Foszfor': 0.00132, 'Magnézium': 0.00182, 'Nátrium': 0.00052, 'Kalcium': 0.00634, 'B6 vitamin': 0.00672, 'Kolin': 0, 'Niacin - B3 vitamin': 1.824e-05, 'C vitamin': 0.000436, 'Telített zsírsav': 0.056760000000000005, 'Többszörösen telített zsírsav': 0.01802, 'Vas': 0.000133, 'Cink': 1.86e-05, 'Réz': 6.02e-06, 'Mangán': 1.9199999999998e-05, 'Szelén': 0, 'Rost': 0.282, 'Cukor': 0, 'Tiamin - B1 vitamin': 7.199999999999999e-07, 'Riboflavin - B2 vitamin': 3.04e-06, 'Pantoténsav - B5 vitamin': 1.6080000000000002e-05, 'Folát': 2.18, 'E vitamin': 0, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0.0232, 'Béta-karotin': 0, 'Lutein+zeaxantin': 0, 'K vitamin': 0, 'A vitamin': 2.92, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: fehérbor, Proportion_100g: 0.5, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 0.035, 'Zsír': 0.0, 'Szénhidrát': 1.3, 'Víz': 43.43, 'Foszfor': 0.009, 'Magnézium': 0.005, 'Nátrium': 0.0025, 'Kalcium': 0.0045, 'B6 vitamin': 0.025, 'Kolin': 0.00215, 'Niacin - B3 vitamin': 5.4e-05, 'C vitamin': 0, 'Telített zsírsav': 0, 'Többszörösen telített zsírsav': 0, 'Vas': 0.000135, 'Cink': 5.999999999995e-05, 'Réz': 2e-06, 'Mangán': 5.85e-05, 'Szelén': 0.05, 'Rost': 0, 'Cukor': 0.48, 'Tiamin - B1 vitamin': 2.5e-06, 'Riboflavin - B2 vitamin': 7.5e-06, 'Pantoténsav - B5 vitamin': 2.25e-05, 'Folát': 0.5, 'E vitamin': 0, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0, 'Béta-karotin': 0, 'Lutein+zeaxantin': 0, 'K vitamin': 0.2, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: tej, Proportion_100g: 2.0, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 6.0, 'Zsír': 2.0, 'Szénhidrát': 8.0, 'Víz': 0.0, 'Foszfor': 0, 'Magnézium': 0, 'Nátrium': 0.1, 'Kalcium': 0.228, 'B6 vitamin': 0, 'Kolin': 0, 'Niacin - B3 vitamin': 0, 'C vitamin': 0, 'Telített zsírsav': 2.0, 'Többszörösen telített zsírsav': 0, 'Vas': 0, 'Cink': 0, 'Réz': 0, 'Mangán': 0, 'Szelén': 0, 'Rost': 0, 'Cukor': 8.0, 'Tiamin - B1 vitamin': 0, 'Riboflavin - B2 vitamin': 0, 'Pantoténsav - B5 vitamin': 0, 'Folát': 0, 'E vitamin': 0, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0, 'Béta-karotin': 0, 'Lutein+zeaxantin': 0, 'K vitamin': 0, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: vaj, Proportion_100g: 0.3, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 0.255, 'Zsír': 64523.0787, 'Szénhidrát': 0.018, 'Víz': 4.851, 'Foszfor': 0.0072, 'Magnézium': 0.0006, 'Nátrium': 0.0032999999999999995, 'Kalcium': 0.0072, 'B6 vitamin': 0.0009, 'Kolin': 0.00564, 'Niacin - B3 vitamin': 1.26e-05, 'C vitamin': 0, 'Telített zsírsav': 15.1467, 'Többszörösen telített zsírsav': 0.9029999999999999, 'Vas': 6e-06, 'Cink': 2.6999999999999996e-05, 'Réz': 4.8e-06, 'Mangán': 1.2e-06, 'Szelén': 0.3, 'Rost': 0, 'Cukor': 0.018, 'Tiamin - B1 vitamin': 1.5e-06, 'Riboflavin - B2 vitamin': 1.0199999999999999e-05, 'Pantoténsav - B5 vitamin': 3.3e-05, 'Folát': 0.8999999999999999, 'E vitamin': 0.000696, 'D vitamin': 0, 'B12 vitamin': 0.051000000000000004, 'Egyszeresen telített zsírsav': 7.029, 'Béta-karotin': 47.4, 'Lutein+zeaxantin': 0, 'K vitamin': 2.1, 'A vitamin': 205.2, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 64.5, 'Retinol': 201.29999999999998, 'Folsav': 0}
# Ingredient: lasagne tészta, Proportion_100g: 2.5, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 32.599999999999994, 'Zsír': 2.5300000000000002, 'Szénhidrát': 186.675, 'Víz': 24.75, 'Foszfor': 0.47250000000000003, 'Magnézium': 0.1325, 'Nátrium': 0.015, 'Kalcium': 0.052500000000000005, 'B6 vitamin': 0.355, 'Kolin': 0.03774999999999975, 'Niacin - B3 vitamin': 0.01794249999999975, 'C vitamin': 0, 'Telített zsírsav': 0.6925000000000001, 'Többszörösen telített zsírsav': 1.41, 'Vas': 0.00825, 'Cink': 0.003525, 'Réz': 0.0007224999999999999, 'Mangán': 0.0022925, 'Szelén': 158.0, 'Rost': 8.0, 'Cukor': 6.675, 'Tiamin - B1 vitamin': 0.0022275, 'Riboflavin - B2 vitamin': 0.001, 'Pantoténsav - B5 vitamin': 0.0010775000000000001, 'Folát': 592.5, 'E vitamin': 0.000275, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0.42750000000000005, 'Béta-karotin': 0, 'Lutein+zeaxantin': 45.0, 'K vitamin': 0.25, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 547.5}
# Ingredient: mascarpone, Proportion_100g: 2.0, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 14.0, 'Zsír': 6.0, 'Szénhidrát': 0.0, 'Víz': 0.0, 'Foszfor': 0, 'Magnézium': 0, 'Nátrium': 0, 'Kalcium': 0, 'B6 vitamin': 0, 'Kolin': 0, 'Niacin - B3 vitamin': 0, 'C vitamin': 0, 'Telített zsírsav': 6.0, 'Többszörösen telített zsírsav': 0, 'Vas': 0, 'Cink': 0, 'Réz': 0, 'Mangán': 0, 'Szelén': 0, 'Rost': 0, 'Cukor': 0, 'Tiamin - B1 vitamin': 0, 'Riboflavin - B2 vitamin': 0, 'Pantoténsav - B5 vitamin': 0, 'Folát': 0, 'E vitamin': 0, 'D vitamin': 0, 'B12 vitamin': 0, 'Egyszeresen telített zsírsav': 0, 'Béta-karotin': 0, 'Lutein+zeaxantin': 0, 'K vitamin': 0, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 0}
# Ingredient: sajt, Proportion_100g: 0.5, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 11.89, 'Zsír': 61513.379, 'Szénhidrát': 0.285, 'Víz': 22.725, 'Foszfor': 0.18, 'Magnézium': 0.012, 'Nátrium': 0.267, 'Kalcium': 0.325, 'B6 vitamin': 0.0265, 'Kolin': 0.0077, 'Niacin - B3 vitamin': 3e-05, 'C vitamin': 0, 'Telített zsírsav': 8.3455, 'Többszörösen telített zsírsav': 0.3645, 'Vas': 0.000215, 'Cink': 0.0013, 'Réz': 1.1e-05, 'Mangán': 5.5e-06, 'Szelén': 7.25, 'Rost': 0, 'Cukor': 0.285, 'Tiamin - B1 vitamin': 7e-06, 'Riboflavin - B2 vitamin': 0.00011999999999995, 'Pantoténsav - B5 vitamin': 0.00010499999999995, 'Folát': 9.0, 'E vitamin': 0.00011999999999995, 'D vitamin': 10.5, 'B12 vitamin': 0.75, 'Egyszeresen telített zsírsav': 4.669, 'Béta-karotin': 14.5, 'Lutein+zeaxantin': 0, 'K vitamin': 1.2, 'A vitamin': 157.5, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 61.5, 'Retinol': 156.5, 'Folsav': 0}
# Ingredient: zsemlemorzsa, Proportion_100g: 0.3, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 4.005, 'Zsír': 1.2857999999999998, 'Szénhidrát': 21.594, 'Víz': 1.9529999999999998, 'Foszfor': 0.0495, 'Magnézium': 0.012899999999999998, 'Nátrium': 0.2196, 'Kalcium': 0.0549, 'B6 vitamin': 0.0363, 'Kolin': 0.00438, 'Niacin - B3 vitamin': 0.0019902, 'C vitamin': 0, 'Telített zsírsav': 0.3609, 'Többszörösen telített zsírsav': 0.618, 'Vas': 0.001449, 'Cink': 0.00043499999999999995, 'Réz': 7.65e-05, 'Mangán': 0.0002757, 'Szelén': 7.56, 'Rost': 1.3499999999999999, 'Cukor': 1.8599999999999999, 'Tiamin - B1 vitamin': 0.0002901, 'Riboflavin - B2 vitamin': 0.00012089999999999998, 'Pantoténsav - B5 vitamin': 0.0001656, 'Folát': 32.1, 'E vitamin': 2.4e-05, 'D vitamin': 0, 'B12 vitamin': 0.105, 'Egyszeresen telített zsírsav': 0.30689999999999995, 'Béta-karotin': 0, 'Lutein+zeaxantin': 0, 'K vitamin': 1.9799999999999998, 'A vitamin': 0, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 0, 'Retinol': 0, 'Folsav': 24.599999999999998}
# Ingredient: vaj, Proportion_100g: 0.3, Nutrition: {'Elsődleges kategória': 0, 'Másodlagos kategória': 0, 'Fehérje': 0.255, 'Zsír': 64523.0787, 'Szénhidrát': 0.018, 'Víz': 4.851, 'Foszfor': 0.0072, 'Magnézium': 0.0006, 'Nátrium': 0.0032999999999999995, 'Kalcium': 0.0072, 'B6 vitamin': 0.0009, 'Kolin': 0.00564, 'Niacin - B3 vitamin': 1.26e-05, 'C vitamin': 0, 'Telített zsírsav': 15.1467, 'Többszörösen telített zsírsav': 0.9029999999999999, 'Vas': 6e-06, 'Cink': 2.6999999999999996e-05, 'Réz': 4.8e-06, 'Mangán': 1.2e-06, 'Szelén': 0.3, 'Rost': 0, 'Cukor': 0.018, 'Tiamin - B1 vitamin': 1.5e-06, 'Riboflavin - B2 vitamin': 1.0199999999999999e-05, 'Pantoténsav - B5 vitamin': 3.3e-05, 'Folát': 0.8999999999999999, 'E vitamin': 0.000696, 'D vitamin': 0, 'B12 vitamin': 0.051000000000000004, 'Egyszeresen telített zsírsav': 7.029, 'Béta-karotin': 47.4, 'Lutein+zeaxantin': 0, 'K vitamin': 2.1, 'A vitamin': 205.2, 'Likopin': 0, 'Alfa-karotin': 0, 'Béta-kriptoxantin': 0, 'koleszterin': 64.5, 'Retinol': 201.29999999999998, 'Folsav': 0}

# %%
calculated_nutrition
# Out:
# [{'Elsődleges kategória': 0,
#   'Másodlagos kategória': 0,
#   'Fehérje': 156.63619999999997,
#   'Zsír': 490656.3327800001,
#   'Szénhidrát': 256.264,
#   'Víz': 722.3854,
#   'Foszfor': 1.5227200000000003,
#   'Magnézium': 0.29742,
#   'Nátrium': 1.06882,
#   'Kalcium': 0.85194,
#   'B6 vitamin': 2.39432,
#   'Kolin': 0.33214999999999945,
#   'Niacin - B3 vitamin': 0.049179139999999746,
#   'C vitamin': 0.035536,
#   'Telített zsírsav': 69.32646,
#   'Többszörösen telített zsírsav': 20.577419999999996,
#   'Vas': 0.015381999999999802,
#   'Cink': 0.01154259999999985,
#   'Réz': 0.0012126199999999998,
#   'Mangán': 0.0032887999999998974,
#   'Szelén': 232.86,
#   'Rost': 17.631999999999998,
#   'Cukor': 32.156000000000006,
#   'Tiamin - B1 vitamin': 0.00297882,
#   'Riboflavin - B2 vitamin': 0.0019238399999995499,
#   'Pantoténsav - B5 vitamin': 0.00596367999999995,
#   'Folát': 727.08,
#   'E vitamin': 0.008375999999999849,
#   'D vitamin': 50.5,
#   'B12 vitamin': 2.197,
#   'Egyszeresen telített zsírsav': 66.4289,
#   'Béta-karotin': 8396.3,
#   'Lutein+zeaxantin': 310.0,
#   'K vitamin': 86.89,
#   'A vitamin': 1569.82,
#   'Likopin': 1.0,
#   'Alfa-karotin': 3477.0,
#   'Béta-kriptoxantin': 0,
#   'koleszterin': 490.5,
#   'Retinol': 723.0999999999999,
#   'Folsav': 572.1}]

# %%
# Running the function
df_receptek = calculate_recipe_nutrition(df_receptek, df_alapanyagok)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17256\2054113728.py in <module>
#       1 # Running the function
# ----> 2 df_receptek = calculate_recipe_nutrition(df_receptek, df_alapanyagok)
#
# ~\AppData\Local\Temp\ipykernel_17256\2057892495.py in calculate_recipe_nutrition(df_receptek, df_alapanyagok)
#      48                 if col in df_alapanyagok.columns:
#      49                     value = matching_ingredient.iloc[0][col]
# ---> 50                     aggregated_nutrition[col] += value * amount_value
#      51
#      52         calculated_nutrition.append(aggregated_nutrition)
#
# TypeError: can't multiply sequence by non-int of type 'float'
